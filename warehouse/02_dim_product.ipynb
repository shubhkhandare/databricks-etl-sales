# %%
silver_path = "/Volumes/workspace/default/etl_sales/silver/sales"

df_silver = spark.read.format("delta").load(silver_path)

# %%
df_silver.display()

# %%
df_dim_product = (df_silver
                  .select('product_id', 'product_name','category')
                  .dropDuplicates(['product_id'])
                  )

# %%
dim_product_path ="/Volumes/workspace/default/etl_sales/warehouse/dim_product"
df_dim_product.write.format('delta').mode("overwrite").saveAsTable("dim_product")
